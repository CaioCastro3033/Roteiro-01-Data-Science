# %% [markdown]
# # Primeiro notebook Jupyter

# %%
# A atividade até aqui está bem descritiva e interessante, pois aborda de forma completa e bem explicada os tópicos necessários para a realização da mesma.

# %%
import pandas as pd

# %%
# !pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Using cached xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\T-GAMER\default_of_credit_card_clients__courseware_version_1_21_19.xls")

# %%
print(f"A planilha possui {df.shape[0]} linhas")
# Out:
# A planilha possui 30000 linhas

# %%
print(f"A planilha possui {df.shape[1]} colunas")
# Out:
# A planilha possui 25 colunas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  object
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
#Lista valores únicos em cada coluna
df.nunique()
# Out:
# ID                            29687
# LIMIT_BAL                        82
# SEX                               3
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              57
# PAY_1                            12
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22510
# BILL_AMT2                     22146
# BILL_AMT3                     21822
# BILL_AMT4                     21350
# BILL_AMT5                     20831
# BILL_AMT6                     20417
# PAY_AMT1                       7890
# PAY_AMT2                       7847
# PAY_AMT3                       7463
# PAY_AMT4                       6901
# PAY_AMT5                       6857
# PAY_AMT6                       6895
# default payment next month        2
# dtype: int64

# %%
#Frequência da característica SEX
df['SEX'].value_counts()
# Out:
# SEX
# 2    17910
# 1    11775
# 0      315
# Name: count, dtype: int64

# %%
#Frequência de EDUCATION
df['EDUCATION'].value_counts()
# Out:
# EDUCATION
# 2    13884
# 1    10474
# 3     4867
# 0      329
# 5      275
# 4      122
# 6       49
# Name: count, dtype: int64

# %%
#Frequência de MARRIAGE
df['MARRIAGE'].value_counts()
# Out:
# MARRIAGE
# 2    15810
# 1    13503
# 0      369
# 3      318
# Name: count, dtype: int64

# %%
#Frequência PAY_2
df['PAY_2'].value_counts()
# Out:
# PAY_2
#  0    15878
# -1     5989
#  2     3878
# -2     3746
#  3      325
#  4       99
#  1       28
#  5       24
#  7       20
#  6       12
#  8        1
# Name: count, dtype: int64

# %%
#Identificação de dados faltantes
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64
